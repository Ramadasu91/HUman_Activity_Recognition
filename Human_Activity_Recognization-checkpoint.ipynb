# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from collections import Counter

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
from sklearn.model_selection import RandomizedSearchCV

# %%
df=pd.read_csv('train.csv')
df.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
# ...

# %%
df_test=pd.read_csv('test.csv')
df_test.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.257178          -0.023285          -0.014654         -0.938404
# 1           0.286027          -0.013163          -0.119083         -0.975415
# 2           0.275485          -0.026050          -0.118152         -0.993819
# 3           0.270298          -0.032614          -0.117520         -0.994743
# 4           0.274833          -0.027848          -0.129527         -0.993852
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.920091         -0.667683         -0.952501         -0.925249
# 1         -0.967458         -0.944958         -0.986799         -0.968401
# 2         -0.969926         -0.962748         -0.994403         -0.970735
# 3         -0.973268         -0.967091         -0.995274         -0.974471
# 4         -0.967445         -0.978295         -0.994111         -0.965953
#
# ...

# %%
df.shape
# Out:
# (7352, 563)

# %%
df_test.shape
# Out:
# (999, 563)

# %%
df.subject.value_counts()
# Out:
# subject
# 25    409
# 21    408
# 26    392
# 30    383
# 28    382
# 27    376
# 23    372
# 17    368
# 16    366
# 19    360
# 1     347
# 29    344
# 3     341
# 15    328
# 6     325
# 14    323
# 22    321
# 11    316
# 7     308
# 5     302
# 8     281
# Name: count, dtype: int64

# %%
df['Activity'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7352 entries, 0 to 7351
# Series name: Activity
# Non-Null Count  Dtype
# --------------  -----
# 7352 non-null   object
# dtypes: object(1)
# memory usage: 57.6+ KB

# %%
df.describe()
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# count        7352.000000        7352.000000        7352.000000
# mean            0.274488          -0.017695          -0.109141
# std             0.070261           0.040811           0.056635
# min            -1.000000          -1.000000          -1.000000
# 25%             0.262975          -0.024863          -0.120993
# 50%             0.277193          -0.017219          -0.108676
# 75%             0.288461          -0.010783          -0.097794
# max             1.000000           1.000000           1.000000
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# count       7352.000000       7352.000000       7352.000000       7352.000000
# mean          -0.605438         -0.510938         -0.604754         -0.630512
# std            0.448734          0.502645          0.418687          0.424073
# min           -1.000000         -0.999873         -1.000000         -1.000000
# ...

# %% [markdown]
# ### Data Wragling

# %% [markdown]
# ### chacking for Duplicates,Null values,class imbalance

# %%
sum(df.duplicated())
# Out:
# 0

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ### EDA

# %%
pd.DataFrame.from_dict(Counter([col.split('-')[0].split('(')[0] for col in df.columns]),orient='index').rename(columns={0:'count'}
                                                                                                              ).sort_values('count',ascending=False)
# Out:
#                       count
# fBodyAcc                 79
# fBodyGyro                79
# fBodyAccJerk             79
# tGravityAcc              40
# tBodyAcc                 40
# tBodyGyroJerk            40
# tBodyGyro                40
# tBodyAccJerk             40
# tBodyAccMag              13
# tGravityAccMag           13
# tBodyAccJerkMag          13
# tBodyGyroMag             13
# tBodyGyroJerkMag         13
# fBodyAccMag              13
# fBodyBodyAccJerkMag      13
# fBodyBodyGyroMag         13
# fBodyBodyGyroJerkMag     13
# angle                     7
# subject                   1
# Activity                  1

# %% [markdown]
# ### Analysing how acceleration strongly  relates to the Body Activity

# %%
facetgrid=sns.FacetGrid(df,hue='Activity',height=5,aspect=3)
facetgrid.map(sns.distplot,'tBodyAccMag-mean()',hist=False).add_legend()

plt.annotate('StaticActivities',xy=(-.98,8),xytext=(-.8,16),arrowprops={"arrowstyle":"-","ls":"dashed"})
plt.annotate('StaticActivities',xy=(-.98,13),xytext=(-.8,16),arrowprops={"arrowstyle":"-","ls":"dashed"})
plt.annotate('StaticActivities',xy=(-.98,16),xytext=(-.8,16),arrowprops={"arrowstyle":"-","ls":"dashed"})

plt.annotate("Dynamic Activities", xy=(-0.2,3.25), xytext=(0.1, 9),arrowprops={'arrowstyle': '-', 'ls': 'dashed'})
plt.annotate("Dynamic Activities", xy=(0.1,2.18), xytext=(0.1, 9),arrowprops={'arrowstyle': '-', 'ls': 'dashed'})
plt.annotate("Dynamic Activities", xy=(-0.01,2.15), xytext=(0.1, 9),arrowprops={'arrowstyle': '-', 'ls': 'dashed'})
plt.show()
# Out:
# C:\Users\Ramtej\Desktop\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# C:\Users\Ramtej\Desktop\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
df['Activity'].unique()
# Out:
# array(['STANDING', 'SITTING', 'LAYING', 'WALKING', 'WALKING_DOWNSTAIRS',
#        'WALKING_UPSTAIRS'], dtype=object)

# %%
sns.distplot(df[df['Activity']=='STANDING']['tBodyAccMag-mean()'],hist=False,label='STANDING')
sns.distplot(df[df['Activity']=='SITTING']['tBodyAccMag-mean()'],hist=False,label='SITTING')
sns.distplot(df[df['Activity']=='LAYING']['tBodyAccMag-mean()'],hist=False,label='LAYING')
# Out:
# C:\Users\Ramtej\AppData\Local\Temp\ipykernel_3360\2527280304.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Activity']=='STANDING']['tBodyAccMag-mean()'],hist=False,label='STANDING')
# C:\Users\Ramtej\AppData\Local\Temp\ipykernel_3360\2527280304.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
sns.distplot(df[df['Activity']=='WALKING']['tBodyAccMag-mean()'],hist=False,label='WALKING')
sns.distplot(df[df['Activity']=='WALKING_DOWNSTAIRS']['tBodyAccMag-mean()'],hist=False,label='WALKING_DOWNSTARIS')
sns.distplot(df[df['Activity']=='WALKING_UPSTAIRS']['tBodyAccMag-mean()'],hist=False,label='WALKING_UPSTAIRS')
# Out:
# C:\Users\Ramtej\AppData\Local\Temp\ipykernel_3360\1313348152.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Activity']=='WALKING']['tBodyAccMag-mean()'],hist=False,label='WALKING')
# C:\Users\Ramtej\AppData\Local\Temp\ipykernel_3360\1313348152.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
sns.boxplot(x='Activity',y='tBodyAccMag-mean()',data=df,showfliers=False)
plt.axhline(y = -0.8, xmin = 0.05, dashes = (3,3))
plt.axhline(y= 0.0, xmin = 0.35, dashes=(3,3))

# %% [markdown]
# ### How Body x-axis and gravity is linked to Body Activity

# %%
sns.boxplot(x='Activity',y='angle(X,gravityMean)',data=df,showfliers=False)
plt.axhline(y=0.00,xmin=0.05,dashes=(3,3))

# %% [markdown]
# #### Except Laying  all other Activities the back body is 0 degree with respect to gravity,but Laying is 90 degree or perpendicular tto gravity

# %%
sns.boxplot(x='Activity',y='angle(Y,gravityMean)',data=df,showfliers=False)
plt.axhline(y=-0.2,xmin=0.05,dashes=(3,3))

# %% [markdown]
# ### visualization using PCA

# %%
x_for_pca=df.drop(['Activity','subject'],axis=1)

# %%
pca=PCA(n_components=2,random_state=0).fit_transform(x_for_pca)

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x=pca[:,0],y=pca[:,1],hue=df['Activity'])
# Out:
# <Axes: >

# %% [markdown]
# ### Here Standing,sitting,laying are became one cluster and walking,downstairs,upstairs became one cluster

# %% [markdown]
# ### Visualizing using TSNE

# %%
x_for_tsne=df.drop(['Activity','subject'],axis=1)

# %%
tsne=TSNE(n_components=2,random_state=0).fit_transform(x_for_tsne)

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x=tsne[:,0],y=tsne[:,1],hue=df['Activity'])
# Out:
# <Axes: >

# %% [markdown]
# ### Preparing the Data

# %%
x_train=df.drop(['Activity','subject'],axis=1)
y_train=df.Activity

x_test=df_test.drop(['Activity','subject'],axis=1)
y_test=df_test.Activity

# %% [markdown]
# ### Logistic Regression with Hyperparameter Tuning and Cross Validation

# %%
parameters = {'max_iter': [100, 200, 500]}
lr_classifier = LogisticRegression()
lr_classifier_rs = RandomizedSearchCV(lr_classifier, param_distributions= parameters, cv = 5, random_state=42)
lr_classifier_rs.fit(x_train, y_train)
y_pred_lr = lr_classifier_rs.predict(x_test)
# Out:
# C:\Users\Ramtej\Desktop\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:307: UserWarning: The total space of parameters 3 is smaller than n_iter=10. Running 3 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# C:\Users\Ramtej\Desktop\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Ramtej\Desktop\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# ...

# %%
lr_accuracy = accuracy_score(y_test, y_pred_lr)
print("Accuracy using Logistic Regression : ", lr_accuracy)
# Out:
# Accuracy using Logistic Regression :  0.955955955955956

# %%
def plot_confusion_matrix(cm,labels):
    fig, ax = plt.subplots(figsize=(12,8)) # for plotting confusion matrix as image
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]),
    yticks=np.arange(cm.shape[0]),
    xticklabels=labels, yticklabels=labels,
    ylabel='True label',
    xlabel='Predicted label')
    plt.xticks(rotation = 90)
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, int(cm[i, j]),ha="center", va="center",color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()

# %%
cm = confusion_matrix(y_test.values,y_pred_lr)
cm
# Out:
# array([[183,   0,   0,   0,   0,   0],
#        [  0, 147,  20,   0,   0,   3],
#        [  0,   8, 170,   0,   0,   0],
#        [  0,   0,   0, 185,   0,   0],
#        [  0,   0,   0,   0, 134,   0],
#        [  0,   0,   0,  13,   0, 136]], dtype=int64)

# %%
cm = confusion_matrix(y_test.values,y_pred_lr)
plot_confusion_matrix(cm, np.unique(y_pred_lr))

# %%
def get_best_randomsearch_results(model):
    print("Best estimator : ", model.best_estimator_)
    print("Best set of parameters : ", model.best_params_)
    #print("Best score : ", model.best_score_)

# %%
get_best_randomsearch_results(lr_classifier_rs)
# Out:
# Best estimator :  LogisticRegression(max_iter=200)
# Best set of parameters :  {'max_iter': 200}

# %% [markdown]
# ### SVC with Hyperparameter Tuning and Cross validation

# %%
parameters = {
    'kernel': ['linear', 'rbf', 'poly', 'sigmoid'],
    'C': [100, 50]
}

svm_rs = RandomizedSearchCV(SVC(), param_distributions=parameters, cv = 3, random_state=42)
svm_rs.fit(x_train, y_train)
# Out:
# C:\Users\Ramtej\Desktop\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:307: UserWarning: The total space of parameters 8 is smaller than n_iter=10. Running 8 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# RandomizedSearchCV(cv=3, estimator=SVC(),
#                    param_distributions={'C': [100, 50],
#                                         'kernel': ['linear', 'rbf', 'poly',
#                                                    'sigmoid']},
#                    random_state=42)

# %%
y_pred = svm_rs.predict(x_test)

# %%
kernel_svm_accuracy = accuracy_score(y_true=y_test, y_pred=y_pred)
print("Accuracy using Kernel SVM : ", kernel_svm_accuracy)
# Out:
# Accuracy using Kernel SVM :  0.965965965965966

# %%
cm = confusion_matrix(y_test.values,y_pred)
plot_confusion_matrix(cm, np.unique(y_pred))

# %%
get_best_randomsearch_results(svm_rs)
# Out:
# Best estimator :  SVC(C=50)
# Best set of parameters :  {'kernel': 'rbf', 'C': 50}

# %% [markdown]
# ### Decision Tree with Hyperparameter Tuning and Cross Validation

# %%
parameters = {'max_depth': np.arange(2, 10, 2)}

dt_classifier = DecisionTreeClassifier()
dt_classifier_rs = RandomizedSearchCV(dt_classifier, param_distributions = parameters, random_state = 42)
dt_classifier_rs.fit(x_train, y_train)
# Out:
# C:\Users\Ramtej\Desktop\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:307: UserWarning: The total space of parameters 4 is smaller than n_iter=10. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# RandomizedSearchCV(estimator=DecisionTreeClassifier(),
#                    param_distributions={'max_depth': array([2, 4, 6, 8])},
#                    random_state=42)

# %%
y_pred = dt_classifier_rs.predict(x_test)

# %%
dt_accuracy = accuracy_score(y_true=y_test, y_pred=y_pred)
print("Accuracy using Decision tree : ", dt_accuracy)
# Out:
# Accuracy using Decision tree :  0.8568568568568569

# %%
cm = confusion_matrix(y_test.values,y_pred)
plot_confusion_matrix(cm, np.unique(y_pred)) # plotting confusion matrix

# %%
# getting best random search attributes
get_best_randomsearch_results(dt_classifier_rs)
# Out:
# Best estimator :  DecisionTreeClassifier(max_depth=8)
# Best set of parameters :  {'max_depth': 8}

# %% [markdown]
# ### Random forest with Hyperparameter Tuning and Cross Validation

# %%
parameters = {
    'n_estimators':np.arange(20, 101, 10), 
    'max_depth': np.arange(2, 17, 2)
}
rf_classifier = RandomForestClassifier()
rf_classifier_rs = RandomizedSearchCV(rf_classifier, param_distributions=parameters,random_state = 42)
rf_classifier_rs.fit(x_train, y_train)

# %%
# getting best random search attributes
get_best_randomsearch_results(rf_classifier_rs)

# %%
y_pred = rf_classifier_rs.predict(x_test)

# %%
rf_accuracy = accuracy_score(y_true=y_test, y_pred=y_pred)
print("Accuracy using Random forest : ", rf_accuracy)

# %%
cm = confusion_matrix(y_test.values,y_pred)
plot_confusion_matrix(cm, np.unique(y_pred))

# %%
sns.heatmap(cm,annot=True,fmt='.1f',xticklabels=np.unique(y_pred),yticklabels=np.unique(y_pred),cmap=plt.cm.Blues)
